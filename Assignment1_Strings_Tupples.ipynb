# %%
print('Python Assignment 1: Data Structures - Strings & Tuples')
print('1. String Concatenation:')
name='Hello'
index=input('enter your name: ')
first_greeting = name + ' ' + index
print(first_greeting)
topic = ", welcome to Python programming"
full_message = first_greeting + topic
print(full_message)
print()

print('2. String Slicing and Indexing:')
first_character =full_message [0]
print("a) The first character of the string is : ", first_character)
last_character = full_message [-1]
print("b) The last character of the string is : ", last_character)
first_five_characters = full_message [:5]
print("c) The first five characters of the string are : ", first_five_characters)
last_eleven_characters = full_message [-11:]
print("d) The last eleven characters of the string are : ", last_eleven_characters)
reversed_string = full_message [::-1]
print("e) The string in reverse is : ", reversed_string)
python_word = full_message[23:29]
print("f) Use slicing and print the word “Python” from the existing string is :", python_word)
print()
print('3. String Methods:')
strM = "Python beginner tutorial"
print("a) The upper case letter is : " , strM.upper())
print("b) The lower case letter is : ", strM.lower())
print("c) Capitalise and return the sentence in original form is : ", strM.capitalize())
print("d) The total number of occurrences of character, 't' is : ", strM.count('t'))
print("e) Replace all occurences of Python in the strM string is : " ,strM.replace('Python' , 'Machine Learning'))
print()
print("4. Tuples (Creation, Modification and Access) : ")
tuple1 = (10, 20, 30)
tuple2 = (40, 50, 60)
t_combine = tuple1 + tuple2
print('a) Concatenate the two tuples and store it in “t_combine” is: ', t_combine)
print('b) Repeat the elements of “t_combine” 3 times is : ', t_combine*3)
print('c) Access the 3rd element from “t_combine” is : ', t_combine[2])
print('d) Access the first three elements from “t_combine” is :', t_combine[:3])
print('e) Access the last three elements from “t_combine” is:', t_combine[-3:])
# Out:
# Python Assignment 1: Data Structures - Strings & Tuples
# 1. String Concatenation:
# enter your name: Zara
# Hello Zara
# Hello Zara, welcome to Python programming
#
# 2. String Slicing and Indexing:
# a) The first character of the string is :  H
# b) The last character of the string is :  g
# c) The first five characters of the string are :  Hello
# d) The last eleven characters of the string are :  programming
# e) The string in reverse is :  gnimmargorp nohtyP ot emoclew ,araZ olleH
# f) Use slicing and print the word “Python” from the existing string is : Python
#
# 3. String Methods:
# a) The upper case letter is :  PYTHON BEGINNER TUTORIAL
# b) The lower case letter is :  python beginner tutorial
# c) Capitalise and return the sentence in original form is :  Python beginner tutorial
# d) The total number of occurrences of character, 't' is :  3
# e) Replace all occurences of Python in the strM string is :  Machine Learning beginner tutorial
#
# ...
